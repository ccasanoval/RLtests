# %% [markdown]
# <a href="https://colab.research.google.com/github/ccasanoval/RLtests/blob/master/LanderV0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lunar Lander v0 for HuggingFace

# %% [markdown]
# Install required libs

# %%
# !pip install stable-baselines3==2.0.0a5
# !pip install swig
# !pip install gymnasium[box2d]
# !pip install huggingface_sb3
# Out:
# Collecting stable-baselines3==2.0.0a5
#   Downloading stable_baselines3-2.0.0a5-py3-none-any.whl.metadata (5.3 kB)
# Collecting gymnasium==0.28.1 (from stable-baselines3==2.0.0a5)
#   Downloading gymnasium-0.28.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5) (1.26.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5) (2.3.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5) (2.1.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5) (3.7.1)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->stable-baselines3==2.0.0a5)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0a5) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.28.1->stable-baselines3==2.0.0a5)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3==2.0.0a5) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3==2.0.0a5) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a5) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0a5) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3==2.0.0a5) (1.3.0)
# Downloading stable_baselines3-2.0.0a5-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.5/177.5 kB 6.0 MB/s eta 0:00:00
# Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 33.4 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: farama-notifications, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jax-jumpy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, gymnasium, nvidia-cusolver-cu12, stable-baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 stable-baselines3-2.0.0a5
# Collecting swig
#   Downloading swig-4.2.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.6 kB)
# Downloading swig-4.2.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 24.7 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.2.1
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.3 (from gymnasium[box2d])
#   Downloading pygame-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.2.1)
# Downloading pygame-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 68.6 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2376100 sha256=8739cbf40c7942119684808e2d76269d737f31702c913f6a26d0fc561f913162
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: box2d-py, pygame
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.6.0
#     Uninstalling pygame-2.6.0:
#       Successfully uninstalled pygame-2.6.0
# Successfully installed box2d-py-2.3.5 pygame-2.1.3
# Collecting huggingface_sb3
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (0.23.5)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (6.0.2)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (2.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2024.7.4)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Installing collected packages: huggingface_sb3
# Successfully installed huggingface_sb3-3.0

# %%
# !pip install pyvirtualdisplay
# Out:
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
import os
os.kill(os.getpid(), 9)

# %%
from pyvirtualdisplay import Display
virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-f60a980366aa> in <cell line: 2>()
#       1 from pyvirtualdisplay import Display
# ----> 2 virtual_display = Display(visible=0, size=(1400, 900))
#       3 virtual_display.start()
#
# /usr/local/lib/python3.10/dist-packages/pyvirtualdisplay/display.py in __init__(self, backend, visible, size, color_depth, bgcolor, use_xauth, retries, extra_args, manage_global_env, **kwargs)
#      52             raise ValueError("unknown backend: %s" % self._backend)
#      53
# ---> 54         self._obj = cls(
#      55             size=size,
#      56             color_depth=color_depth,
#
# /usr/local/lib/python3.10/dist-packages/pyvirtualdisplay/xvfb.py in __init__(self, size, color_depth, bgcolor, use_xauth, fbdir, dpi, retries, extra_args, manage_global_env)
#      42         self._dpi = dpi
#      43
# ---> 44         AbstractDisplay.__init__(
#      45             self,
#      46             PROGRAM,
#
# /usr/local/lib/python3.10/dist-packages/pyvirtualdisplay/abstractdisplay.py in __init__(self, program, use_xauth, retries, extra_args, manage_global_env)
#      83         self._retries_current = 0
#      84
# ---> 85         helptext = get_helptext(program)
#      86         self._has_displayfd = "-displayfd" in helptext
#      87         if not self._has_displayfd:
#
# /usr/local/lib/python3.10/dist-packages/pyvirtualdisplay/util.py in get_helptext(program)
#      11
#      12     # py3.6 also
# ---> 13     p = subprocess.Popen(
#      14         cmd,
#      15         stdout=subprocess.PIPE,
#
# /usr/lib/python3.10/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     969                             encoding=encoding, errors=errors)
#     970
# --> 971             self._execute_child(args, executable, preexec_fn, close_fds,
#     972                                 pass_fds, cwd, env,
#     973                                 startupinfo, creationflags, shell,
#
# /usr/lib/python3.10/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1861                     if errno_num != 0:
#    1862                         err_msg = os.strerror(errno_num)
# -> 1863                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1864                 raise child_exception_type(err_msg)
#    1865
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Xvfb'

# %% [markdown]
# Import required libs

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import (
    notebook_login,
)  # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %% [markdown]
# Play around with the env

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
    # Take a random action
    action = env.action_space.sample()
    print("Action taken:", action)

    # Do this action in the environment and get
    # next_state, reward, terminated, truncated and info
    observation, reward, terminated, truncated, info = env.step(action)

    # If the game is terminated (in our case we land, crashed) or truncated (timeout)
    if terminated or truncated:
        # Reset the environment
        print("Environment is reset")
        observation, info = env.reset()

env.close()
# Out:
# Action taken: 2
# Action taken: 3
# Action taken: 0
# Action taken: 3
# Action taken: 0
# Action taken: 1
# Action taken: 0
# Action taken: 3
# Action taken: 2
# Action taken: 0
# Action taken: 1
# Action taken: 3
# Action taken: 1
# Action taken: 2
# Action taken: 1
# Action taken: 2
# Action taken: 2
# Action taken: 1
# Action taken: 3
# Action taken: 3
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v2")
env.reset()

print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample())  # Get a random observation

print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample())  # Take a random action
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [ 43.105686   -59.092484     3.3241234    0.46600187   0.47528875
#   -1.4407223    0.61227465   0.96833867]
#
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 2

# %% [markdown]
# Create Agent Algo and Train it

# %%
#Vectorized env
env = make_vec_env("LunarLander-v2", n_envs=16)

#env = gym.make('LunarLander-v2')

# Instantiate the agent
#model = PPO('MlpPolicy', env, verbose=1)
model = PPO(
    policy="MlpPolicy",
    env=env,
    n_steps=1024,
    batch_size=64,
    n_epochs=4,
    gamma=0.999,
    gae_lambda=0.98,
    ent_coef=0.01,
    verbose=1,
)

# Train the agent
model.learn(total_timesteps=int(1e6))
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96       |
# |    ep_rew_mean     | -209     |
# | time/              |          |
# |    fps             | 2897     |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.3        |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 2071        |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009165821 |
# |    clip_fraction        | 0.0663      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00209     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.44e+03    |
# |    n_updates            | 4           |
# |    policy_gradient_loss | -0.00672    |
# |    value_loss           | 5.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.3        |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 1979        |
# |    iterations           | 3           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008413101 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00201    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 736         |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00722    |
# |    value_loss           | 2.49e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.4        |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 1912        |
# |    iterations           | 4           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008041352 |
# |    clip_fraction        | 0.0498      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00847     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 225         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 977         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -90.7       |
# | time/                   |             |
# |    fps                  | 1827        |
# |    iterations           | 5           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010434262 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.00808     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 266         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00591    |
# |    value_loss           | 679         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | -78.7       |
# | time/                   |             |
# |    fps                  | 1780        |
# |    iterations           | 6           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009455769 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0302      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 524         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00681    |
# |    value_loss           | 495         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -64.1       |
# | time/                   |             |
# |    fps                  | 1784        |
# |    iterations           | 7           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.005981944 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.0448     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 219         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 485         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | -43.9        |
# | time/                   |              |
# |    fps                  | 1758         |
# |    iterations           | 8            |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0110073015 |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -5.64e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 283          |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.00722     |
# |    value_loss           | 480          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | -21.5        |
# | time/                   |              |
# |    fps                  | 1747         |
# |    iterations           | 9            |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0074279765 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | -0.00129     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 148          |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 443          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 154         |
# |    ep_rew_mean          | -11.3       |
# | time/                   |             |
# |    fps                  | 1648        |
# |    iterations           | 10          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.008647043 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | -3.93e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 268         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00293    |
# |    value_loss           | 459         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 235          |
# |    ep_rew_mean          | -1.32        |
# | time/                   |              |
# |    fps                  | 1517         |
# |    iterations           | 11           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0063183554 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.000404     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 336          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 499          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 284          |
# |    ep_rew_mean          | -4.11        |
# | time/                   |              |
# |    fps                  | 1417         |
# |    iterations           | 12           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0053392956 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.000871     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 204          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 486          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 266          |
# |    ep_rew_mean          | 0.429        |
# | time/                   |              |
# |    fps                  | 1356         |
# |    iterations           | 13           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0036280956 |
# |    clip_fraction        | 0.00691      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 158          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 470          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 324          |
# |    ep_rew_mean          | 5.54         |
# | time/                   |              |
# |    fps                  | 1288         |
# |    iterations           | 14           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0064336015 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.472        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 107          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 369          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 382         |
# |    ep_rew_mean          | 8.07        |
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 15          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.004022911 |
# |    clip_fraction        | 0.0165      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 279         |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.0012     |
# |    value_loss           | 368         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 451          |
# |    ep_rew_mean          | 14.4         |
# | time/                   |              |
# |    fps                  | 1194         |
# |    iterations           | 16           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0046741213 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.572        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 139          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 343          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 515          |
# |    ep_rew_mean          | 17           |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 17           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0043659983 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.699        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 107          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 189          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 557        |
# |    ep_rew_mean          | 16.3       |
# | time/                   |            |
# |    fps                  | 1119       |
# |    iterations           | 18         |
# |    time_elapsed         | 263        |
# |    total_timesteps      | 294912     |
# | train/                  |            |
# |    approx_kl            | 0.00491871 |
# |    clip_fraction        | 0.0239     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | 0.674      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 167        |
# |    n_updates            | 68         |
# |    policy_gradient_loss | -0.0012    |
# |    value_loss           | 225        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 650          |
# |    ep_rew_mean          | 29.5         |
# | time/                   |              |
# |    fps                  | 1093         |
# |    iterations           | 19           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0057826573 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.663        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.2         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 208          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 694         |
# |    ep_rew_mean          | 32.1        |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 20          |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.005059478 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 107         |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 170         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 718          |
# |    ep_rew_mean          | 38.2         |
# | time/                   |              |
# |    fps                  | 1040         |
# |    iterations           | 21           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0069108363 |
# |    clip_fraction        | 0.052        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.759        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.1         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 129          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 732         |
# |    ep_rew_mean          | 38.5        |
# | time/                   |             |
# |    fps                  | 1021        |
# |    iterations           | 22          |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.005763009 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 108         |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 135         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 737         |
# |    ep_rew_mean          | 44.9        |
# | time/                   |             |
# |    fps                  | 1005        |
# |    iterations           | 23          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.004609854 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.7        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 110         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 746          |
# |    ep_rew_mean          | 41.7         |
# | time/                   |              |
# |    fps                  | 989          |
# |    iterations           | 24           |
# |    time_elapsed         | 397          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0040241634 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.6         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.000431    |
# |    value_loss           | 97.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 787         |
# |    ep_rew_mean          | 56.6        |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 25          |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.004478936 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.9        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00214    |
# |    value_loss           | 134         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 773          |
# |    ep_rew_mean          | 62.3         |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 26           |
# |    time_elapsed         | 443          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0047402577 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 61.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 820         |
# |    ep_rew_mean          | 73.1        |
# | time/                   |             |
# |    fps                  | 944         |
# |    iterations           | 27          |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.003851024 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.5        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 78.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 848          |
# |    ep_rew_mean          | 79.7         |
# | time/                   |              |
# |    fps                  | 930          |
# |    iterations           | 28           |
# |    time_elapsed         | 492          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0037557504 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.905        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.14         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.000377    |
# |    value_loss           | 68.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 892         |
# |    ep_rew_mean          | 88.8        |
# | time/                   |             |
# |    fps                  | 913         |
# |    iterations           | 29          |
# |    time_elapsed         | 520         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.006645599 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 32.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 919         |
# |    ep_rew_mean          | 95.3        |
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 30          |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.004928492 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.99        |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.00169    |
# |    value_loss           | 44.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 934         |
# |    ep_rew_mean          | 98.4        |
# | time/                   |             |
# |    fps                  | 889         |
# |    iterations           | 31          |
# |    time_elapsed         | 571         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.005110039 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.000682   |
# |    value_loss           | 36.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 953        |
# |    ep_rew_mean          | 103        |
# | time/                   |            |
# |    fps                  | 879        |
# |    iterations           | 32         |
# |    time_elapsed         | 596        |
# |    total_timesteps      | 524288     |
# | train/                  |            |
# |    approx_kl            | 0.00326653 |
# |    clip_fraction        | 0.035      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.98       |
# |    n_updates            | 124        |
# |    policy_gradient_loss | 9.18e-05   |
# |    value_loss           | 20.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 953          |
# |    ep_rew_mean          | 107          |
# | time/                   |              |
# |    fps                  | 874          |
# |    iterations           | 33           |
# |    time_elapsed         | 618          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0066585355 |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.89         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 21.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 945         |
# |    ep_rew_mean          | 112         |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 34          |
# |    time_elapsed         | 642         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.004787723 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.08        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 24.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 912         |
# |    ep_rew_mean          | 111         |
# | time/                   |             |
# |    fps                  | 857         |
# |    iterations           | 35          |
# |    time_elapsed         | 668         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.003671588 |
# |    clip_fraction        | 0.0231      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.55        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -9.49e-05   |
# |    value_loss           | 37.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 905          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 852          |
# |    iterations           | 36           |
# |    time_elapsed         | 691          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0037163682 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.2         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000905    |
# |    value_loss           | 49.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 917         |
# |    ep_rew_mean          | 119         |
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 37          |
# |    time_elapsed         | 714         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.004564642 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 38.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 917          |
# |    ep_rew_mean          | 122          |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 38           |
# |    time_elapsed         | 737          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0038306126 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.6          |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 21.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | 123          |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 39           |
# |    time_elapsed         | 759          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0038924795 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.959       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.9         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.000254    |
# |    value_loss           | 18           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 930          |
# |    ep_rew_mean          | 125          |
# | time/                   |              |
# |    fps                  | 838          |
# |    iterations           | 40           |
# |    time_elapsed         | 781          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0054759597 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.922       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.99         |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.0006      |
# |    value_loss           | 17.7         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 936       |
# |    ep_rew_mean          | 128       |
# | time/                   |           |
# |    fps                  | 835       |
# |    iterations           | 41        |
# |    time_elapsed         | 803       |
# |    total_timesteps      | 671744    |
# | train/                  |           |
# |    approx_kl            | 0.0041025 |
# |    clip_fraction        | 0.0331    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.877    |
# |    explained_variance   | 0.983     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.73      |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -0.000509 |
# |    value_loss           | 20.5      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 951          |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 833          |
# |    iterations           | 42           |
# |    time_elapsed         | 825          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0029123342 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.916       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.79         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -9.81e-05    |
# |    value_loss           | 24.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 937          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 43           |
# |    time_elapsed         | 848          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0071157115 |
# |    clip_fraction        | 0.0643       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.871       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.3         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.000976    |
# |    value_loss           | 32.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 916          |
# |    ep_rew_mean          | 132          |
# | time/                   |              |
# |    fps                  | 827          |
# |    iterations           | 44           |
# |    time_elapsed         | 871          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0039633494 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.864       |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.6         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.000304    |
# |    value_loss           | 40.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 922          |
# |    ep_rew_mean          | 134          |
# | time/                   |              |
# |    fps                  | 826          |
# |    iterations           | 45           |
# |    time_elapsed         | 892          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0035432964 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.833       |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.42         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.000654    |
# |    value_loss           | 59.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 914          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 824          |
# |    iterations           | 46           |
# |    time_elapsed         | 914          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0048699426 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.5          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000184    |
# |    value_loss           | 28           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 911         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 47          |
# |    time_elapsed         | 936         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.002981264 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.61        |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.000968   |
# |    value_loss           | 46.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 913          |
# |    ep_rew_mean          | 151          |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 48           |
# |    time_elapsed         | 957          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0047530807 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.802       |
# |    explained_variance   | 0.893        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.5         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 133          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 906          |
# |    ep_rew_mean          | 161          |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 49           |
# |    time_elapsed         | 977          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0036455658 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.762       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.23         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 64.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 838         |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 50          |
# |    time_elapsed         | 997         |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.004278144 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.764      |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52          |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 153         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 756         |
# |    ep_rew_mean          | 201         |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 51          |
# |    time_elapsed         | 1015        |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.006266783 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00371    |
# |    value_loss           | 288         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 583          |
# |    ep_rew_mean          | 233          |
# | time/                   |              |
# |    fps                  | 825          |
# |    iterations           | 52           |
# |    time_elapsed         | 1031         |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0047000176 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.729       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 155          |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 272          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 449        |
# |    ep_rew_mean          | 243        |
# | time/                   |            |
# |    fps                  | 829        |
# |    iterations           | 53         |
# |    time_elapsed         | 1047       |
# |    total_timesteps      | 868352     |
# | train/                  |            |
# |    approx_kl            | 0.01123181 |
# |    clip_fraction        | 0.0869     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.795     |
# |    explained_variance   | 0.669      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 153        |
# |    n_updates            | 208        |
# |    policy_gradient_loss | -0.00354   |
# |    value_loss           | 247        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 378         |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 54          |
# |    time_elapsed         | 1061        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.007009404 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.3        |
# |    n_updates            | 212         |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 180         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 330          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 838          |
# |    iterations           | 55           |
# |    time_elapsed         | 1074         |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0036186753 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.801       |
# |    explained_variance   | 0.521        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 233          |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.000919    |
# |    value_loss           | 234          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 338          |
# |    ep_rew_mean          | 229          |
# | time/                   |              |
# |    fps                  | 842          |
# |    iterations           | 56           |
# |    time_elapsed         | 1089         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0039304234 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.8         |
# |    explained_variance   | 0.461        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 95.1         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 436          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 342          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 57           |
# |    time_elapsed         | 1103         |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0041402765 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.2         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 247          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 327         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 58          |
# |    time_elapsed         | 1116        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.003605381 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 228         |
# |    policy_gradient_loss | 3.2e-06     |
# |    value_loss           | 159         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 855         |
# |    iterations           | 59          |
# |    time_elapsed         | 1129        |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.003528724 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 232         |
# |    policy_gradient_loss | -3.47e-05   |
# |    value_loss           | 85.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 332          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 60           |
# |    time_elapsed         | 1143         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0053419834 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.79        |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.5         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | 1.02e-05     |
# |    value_loss           | 90.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 332          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 864          |
# |    iterations           | 61           |
# |    time_elapsed         | 1156         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0034041652 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.4         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000205     |
# |    value_loss           | 154          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 327         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 62          |
# |    time_elapsed         | 1170        |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.005348026 |
# |    clip_fraction        | 0.0632      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.832      |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 244         |
# |    policy_gradient_loss | -0.00049    |
# |    value_loss           | 83.5        |
# -----------------------------------------

# %% [markdown]
# Evaluate the Agent

# %%
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=257.32 +/- 22.711605826300385
